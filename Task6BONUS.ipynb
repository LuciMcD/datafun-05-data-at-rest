# %% [markdown]
# # Task 6. BONUS
# Importing data on entry disproportionality rates by ethnicity.

# %%
import pandas as pd

entry_DCF = pd.read_csv('Children_Entering_DCF_Placement.csv')

# %%
entry_DCF.head()
# Out:
#   Data_as_of DCF Region         DCF Office Demographic   SFY  TOTAL_ENTRY  \
# 0   8/6/2015      Other              Other       BLACK  2005           77
# 1   8/6/2015      Other              Other    HISPANIC  2005           70
# 2   8/6/2015      Other              Other       OTHER  2005           23
# 3   8/6/2015      Other              Other       WHITE  2005           61
# 4   8/6/2015   Region 1  Bridgeport Office       BLACK  2005          126
#
#    FOSTER_CARE  RELATIVE_CARE  SPECIAL_STUDY  THERAPEUTIC_FOSTER_CARE  \
# 0            3              2              0                        0
# 1            6              0              0                        0
# 2            0              0              0                        0
# 3            2              5              0                        0
# 4           64             12              1                        3
#
#    PDC_SAFE_HOME  SHELTER  GROUP_HOME  RESIDENTIAL  DCF_HIGHMEADOWS  \
# ...

# %%
entry_DCF.tail()
# Out:
#     Data_as_of DCF Region         DCF Office         Demographic   SFY  \
# 961  11/7/2018   Region 6     Meriden Office  Non-Hispanic Other  2018
# 962  11/7/2018   Region 2     Milford Office  Non-Hispanic Other  2018
# 963  11/7/2018   Region 5   Waterbury Office            Hispanic  2018
# 964  11/7/2018   Region 4  Manchester Office  Non-Hispanic Other  2018
# 965  11/7/2018   Region 6     Meriden Office            Hispanic  2018
#
#      TOTAL_ENTRY  FOSTER_CARE  RELATIVE_CARE  SPECIAL_STUDY  \
# 961            7            4              2              0
# 962           17            8              8              1
# 963          124           53             36             14
# 964           16            5              6              1
# 965           37           15             15              3
#
#      THERAPEUTIC_FOSTER_CARE  PDC_SAFE_HOME  SHELTER  GROUP_HOME  RESIDENTIAL  \
# 961                        0              0        0           0            0
# ...

# %% [markdown]
# ### Describing the dataset
# SFY stands for State Fiscal year. Therefore the data under the column SFY below can be ignored.

# %%
pd.options.display.float_format = '{:,.2f}'.format
entry_DCF.describe()
# Out:
#            SFY  TOTAL_ENTRY  FOSTER_CARE  RELATIVE_CARE  SPECIAL_STUDY  \
# count   966.00       966.00       966.00         966.00         966.00
# mean  2,011.81        38.89        16.95           8.33           1.39
# std       4.08        39.47        19.24          10.12           2.16
# min   2,005.00         1.00         0.00           0.00           0.00
# 25%   2,008.00        10.00         4.00           1.00           0.00
# 50%   2,012.00        25.00        10.00           5.00           0.00
# 75%   2,016.00        55.00        23.00          12.00           2.00
# max   2,018.00       220.00       129.00          57.00          14.00
#
#        THERAPEUTIC_FOSTER_CARE  PDC_SAFE_HOME  SHELTER  GROUP_HOME  \
# count                   966.00         966.00   966.00      966.00
# mean                      1.04           3.06     1.61        0.76
# std                       1.96           5.43     2.36        1.35
# ...

# %% [markdown]
# ## Creating a Histogram

# %%
histogram = (entry_DCF.TOTAL_ENTRY).hist()

# %%
histogram = (entry_DCF.FOSTER_CARE).hist()

# %%
histogram = (entry_DCF.RELATIVE_CARE).hist()

# %%
histogram = (entry_DCF.SPECIAL_STUDY).hist()

# %%
histogram = (entry_DCF.THERAPEUTIC_FOSTER_CARE).hist()

# %%
histogram = (entry_DCF.PDC_SAFE_HOME).hist()

# %%
histogram = (entry_DCF.SHELTER).hist()

# %%
histogram = (entry_DCF.GROUP_HOME).hist()

# %%
histogram = (entry_DCF.RESIDENTIAL).hist()

# %%
histogram = (entry_DCF.DCF_HIGHMEADOWS).hist()

# %%
histogram = (entry_DCF.DCF_SOLNIT).hist()

# %%
histogram = (entry_DCF.DCF_CJTS).hist()

# %%
histogram = (entry_DCF.HOSPITAL).hist()

# %%
histogram = (entry_DCF.INDEPENDENT_LIVING).hist()
